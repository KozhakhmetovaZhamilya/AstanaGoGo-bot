# %%
pip install python-telegram-bot

# %%
# !pip install nest_asyncio --quiet

# %%
from telegram import Update, InlineKeyboardButton, InlineKeyboardMarkup
from telegram.ext import Application, CommandHandler, CallbackQueryHandler, ContextTypes

# %%
TOKEN = "8106659815:AAG3CFwyeQH7R0Cto-NfPLmJ6qT8zdRWOrA"

# %%
categories = [
    "Cafes",
    "Restaurants",
    "Cinema",
    "Bowling",
    "Karaoke",
    "Coworking",
    "Oceanarium",
    "Exhibitions",
    "Museums",
    "Parks"
]


async def start(update: Update, context: ContextTypes.DEFAULT_TYPE):
    keyboard = [
        [InlineKeyboardButton("Cafes", callback_data="category_Cafes"),
         InlineKeyboardButton("Restaurants", callback_data="category_Restaurants")],

        [InlineKeyboardButton("Cinema", callback_data="category_Cinema"),
         InlineKeyboardButton("Bowling", callback_data="category_Bowling")],

        [InlineKeyboardButton("Karaoke", callback_data="category_Karaoke"),
         InlineKeyboardButton("Coworking", callback_data="category_Coworking")],

        [InlineKeyboardButton("Oceanarium", callback_data="category_Oceanarium"),
         InlineKeyboardButton("Exhibitions", callback_data="category_Exhibitions")],

        [InlineKeyboardButton("Museums", callback_data="category_Museums"),
         InlineKeyboardButton("Parks", callback_data="category_Parks")]
    ]

    await update.message.reply_text(
        "Hi! I am AstanaGo Bot.\nWhere would you like to go today?",
        reply_markup=InlineKeyboardMarkup(keyboard)
    )

async def button_handler(update: Update, context: ContextTypes.DEFAULT_TYPE):
    query = update.callback_query
    await query.answer()

    data = query.data
    print("Button clicked:", data)

    if data in ["go_main_menu", "choose_category"]:
        keyboard = [
            [InlineKeyboardButton("Cafes", callback_data="category_Cafes"),
             InlineKeyboardButton("Restaurants", callback_data="category_Restaurants")],

            [InlineKeyboardButton("Cinema", callback_data="category_Cinema"),
             InlineKeyboardButton("Bowling", callback_data="category_Bowling")],

            [InlineKeyboardButton("Karaoke", callback_data="category_Karaoke"),
             InlineKeyboardButton("Coworking", callback_data="category_Coworking")],

            [InlineKeyboardButton("Oceanarium", callback_data="category_Oceanarium"),
             InlineKeyboardButton("Exhibitions", callback_data="category_Exhibitions")],

            [InlineKeyboardButton("Museums", callback_data="category_Museums"),
             InlineKeyboardButton("Parks", callback_data="category_Parks")]
        ]

        await query.message.reply_text(
            "Where would you like to go today?",
            reply_markup=InlineKeyboardMarkup(keyboard)
        )
        return

    data = query.data
    print("Button clicked:", data)

    if data.startswith("category_"):
        category = data.replace("category_", "")
        context.user_data["category"] = category

        if category == "Cafes":
            await query.message.reply_text(
                "What is the purpose of your visit?",
                reply_markup=cafe_purpose_buttons()
            )

        elif category == "Restaurants":
            await query.message.reply_text(
                "What type of food would you like?",
                reply_markup=restaurant_cuisine_buttons()
            )

        elif category == "Cinema":
            await query.message.reply_text(
                "Which cinema would you like to visit?",
                reply_markup=cinema_buttons()
            )

        elif category == "Bowling":
            await query.message.reply_text(
                "How many people will play?",
                reply_markup=bowling_group_buttons()
            )

        elif category == "Karaoke":
            keyboard = [
                [InlineKeyboardButton("Up to 50,000 KZT", callback_data="karaoke_budget_Up to 50,000 KZT")],
                [InlineKeyboardButton("50,000 - 100,000 KZT", callback_data="karaoke_budget_50,000 - 100,000 KZT")],
                [InlineKeyboardButton("100,000 - 200,000 KZT", callback_data="karaoke_budget_100,000 - 200,000 KZT")],
                [InlineKeyboardButton("200,000+ KZT", callback_data="karaoke_budget_200,000+ KZT")]
            ]
            await query.message.reply_text(
                "What is your karaoke budget?",
                reply_markup=karaoke_budget_buttons()
            )

        elif category == "Coworking":
            keyboard = [
                [InlineKeyboardButton("Study", callback_data="coworking_Study")],
                [InlineKeyboardButton("Quiet work", callback_data="coworking_Quiet work")],
                [InlineKeyboardButton("Work meeting", callback_data="coworking_Work meeting")],
                [InlineKeyboardButton("Creative space", callback_data="coworking_Creative space")]
            ]
            await query.message.reply_text(
                "What do you need a coworking space for?",
                reply_markup=coworking_purpose_buttons()
            )

        elif category == "Oceanarium":
            keyboard = [
                [InlineKeyboardButton("1 adult", callback_data="adult_1")],
                [InlineKeyboardButton("2 adults", callback_data="adult_2")],
                [InlineKeyboardButton("3 adults", callback_data="adult_3")],
                [InlineKeyboardButton("4 adults", callback_data="adult_4")]
            ]
            await query.message.reply_text(
                "Ailand Oceanarium has tickets for adults and children.\nPlease choose the number of adults:",
                reply_markup=oceanarium_adult_buttons()
            )

        elif category == "Exhibitions":
            keyboard = [
                [InlineKeyboardButton("Art gallery", callback_data="exhibition_Art gallery")],
                [InlineKeyboardButton("Modern art", callback_data="exhibition_Modern art")],
                [InlineKeyboardButton("Cultural exhibition", callback_data="exhibition_Cultural exhibition")]
            ]
            await query.message.reply_text(
                "What kind of exhibition are you interested in?",
                reply_markup=exhibition_type_buttons()
            )

        elif category == "Museums":
            keyboard = [
                [InlineKeyboardButton("National Museum", callback_data="museum_National Museum")],
                [InlineKeyboardButton("Saken Seifullin Museum", callback_data="museum_Saken Seifullin Museum")],
                [InlineKeyboardButton("Atameken Ethno-Memorial Complex", callback_data="museum_Atameken")]
            ]
            await query.message.reply_text(
                "Which museum would you like to visit?",
                reply_markup=museum_buttons()
            )

        elif category == "Parks":
            keyboard = [
                [InlineKeyboardButton("Walking", callback_data="park_Walking")],
                [InlineKeyboardButton("Photos", callback_data="park_Photos")],
                [InlineKeyboardButton("Sport", callback_data="park_Sport")],
                [InlineKeyboardButton("Attractions", callback_data="park_Attractions")],
                [InlineKeyboardButton("Dino Park", callback_data="park_Dino Park")],
                [InlineKeyboardButton("Family walk", callback_data="park_Family walk")]
            ]
            await query.message.reply_text(
                "What kind of park activity do you prefer?",
                reply_markup=park_purpose_buttons()
            )

    else:
        await handle_next_steps(query, context, data)

# %%
# FINAL NAVIGATION BUTTONS

def final_navigation_buttons():
    keyboard = [
        [InlineKeyboardButton("🏠 Main menu", callback_data="go_main_menu")],

    ]

    return InlineKeyboardMarkup(keyboard)

# %%
async def handle_next_steps(query, context, data):

    if data.startswith("cafe_purpose_"):
        purpose = data.replace("cafe_purpose_", "")
        context.user_data["cafe_purpose"] = purpose

        await query.message.reply_text(
            "What is your budget?",
            reply_markup=cafe_budget_buttons()
        )

    elif data.startswith("cafe_budget_"):
        budget = data.replace("cafe_budget_", "")
        purpose = context.user_data.get("cafe_purpose")

        cafes = cafe_data.get(purpose, {}).get(budget, [])

        if cafes:
            response = "☕ Here are cafe options for you:\n\n"

            for cafe in cafes:
                response += f"📍 {cafe['name']}\n"
                response += f"Rating: {cafe['rating']}\n"
                response += f"Average check: {cafe['average']}\n"
                response += f"Address: {cafe['address']}\n\n"

            await query.message.reply_text(
                response,
                reply_markup=final_navigation_buttons()
                )
        else:
            await query.message.reply_text(
                "Sorry, I could not find cafes for this choice."
            )

    elif data.startswith("food_"):
        food_type = data.replace("food_", "")
        context.user_data["food_type"] = food_type

        await query.message.reply_text(
            f"You selected: {food_type}\nHere are some recommended restaurants:",
            reply_markup=restaurant_list_buttons(food_type)
        )

    elif data.startswith("restaurant_"):
        restaurant_name = data.replace("restaurant_", "")
        info = restaurant_info.get(restaurant_name)

        if info:
            await query.message.reply_text(
                f"📍 {restaurant_name}\n\n"
                f"{info['average_check']}\n"
                f"{info['working_hours']}\n\n"
                f"{info['description']}\n\n"
                f"Address: {info['address']}",
                reply_markup=final_navigation_buttons()
            )
        else:
            await query.message.reply_text(
                "Sorry, I could not find information about this restaurant."
            )

    elif data.startswith("cinema_"):
        cinema_name = data.replace("cinema_", "")
        info = cinema_info.get(cinema_name)

        if info:
            await query.message.reply_text(
                f"🎬 {cinema_name}\n\n"
                f"{info['price']}\n"
                f"Working hours: {info['working_hours']}\n\n"
                f"{info['description']}\n\n"
                f"Address: {info['address']}",
                reply_markup=final_navigation_buttons()
            )
        else:
            await query.message.reply_text(
                "Sorry, I could not find information about this cinema."
            )

    elif data.startswith("bowling_group_"):
        group_size = data.replace("bowling_group_", "")
        context.user_data["bowling_group"] = group_size

        if group_size == "more_than_6":
            await query.message.reply_text(
                "For more than 6 people, you may need 2 lanes.\nPlease choose a bowling center:",
                reply_markup=bowling_center_buttons()
            )
        else:
            await query.message.reply_text(
                "One lane should be enough for your group.\nPlease choose a bowling center:",
                reply_markup=bowling_center_buttons()
            )

    elif data.startswith("bowling_center_"):
        center_name = data.replace("bowling_center_", "")
        info = bowling_info.get(center_name)

        if info:
            await query.message.reply_text(
                f"🎳 {info['name']}\n\n"
                f"{info['price']}\n"
                f"{info['capacity']}\n"
                f"Working hours: {info['working_hours']}\n\n"
                f"{info['details']}\n\n"
                f"Address: {info['address']}",
                reply_markup=final_navigation_buttons()
            )
        else:
            await query.message.reply_text(
                "Sorry, I could not find information about this bowling center."
            )

    elif data.startswith("ocean_adults_"):
        adults = int(data.replace("ocean_adults_", ""))
        context.user_data["ocean_adults"] = adults

        await query.message.reply_text(
            "How many children under 3 years old are with you?",
            reply_markup=oceanarium_free_children_buttons()
        )

    elif data.startswith("ocean_free_"):
        free_children = int(data.replace("ocean_free_", ""))
        context.user_data["ocean_free_children"] = free_children

        await query.message.reply_text(
            "How many paid children tickets do you need?",
            reply_markup=oceanarium_paid_children_buttons()
        )

    elif data.startswith("ocean_paid_"):
        paid_children = int(data.replace("ocean_paid_", ""))
        adults = context.user_data.get("ocean_adults", 0)
        free_children = context.user_data.get("ocean_free_children", 0)

        adult_total = adults * oceanarium_info["adult_price"]
        child_total = paid_children * oceanarium_info["child_price"]
        total_price = adult_total + child_total

        await query.message.reply_text(
            f"🐠 {oceanarium_info['name']}\n\n"
            f"Adult ticket: {oceanarium_info['adult_price']} KZT\n"
            f"Child ticket: {oceanarium_info['child_price']} KZT\n"
            f"Children under 3 years old: free\n\n"
            f"Adults: {adults} × {oceanarium_info['adult_price']} = {adult_total} KZT\n"
            f"Paid children: {paid_children} × {oceanarium_info['child_price']} = {child_total} KZT\n"
            f"Children under 3: {free_children} (free)\n\n"
            f"Estimated total price: {total_price} KZT\n\n"
            f"{oceanarium_info['working_hours']}\n\n"
            f"{oceanarium_info['description']}\n\n"
            f"Address: {oceanarium_info['address']}",
            reply_markup=final_navigation_buttons()
        )

    elif data.startswith("museum_") and not data.startswith("museum_adults_") and not data.startswith("museum_students_") and not data.startswith("museum_pupils_") and not data.startswith("museum_free_"):
        museum_key = data.replace("museum_", "")
        context.user_data["selected_museum"] = museum_key

        if museum_key == "First President":
            info = museum_info.get("First President")
            await query.message.reply_text(
                f"🏛 {info['name']}\n\n"
                f"Entrance: Free\n\n"
                f"Working hours: {info['working_hours']}\n\n"
                f"{info['description']}\n\n"
                f"Address: {info['address']}\n\n"
                f"Note: {info['note']}",
                reply_markup=final_navigation_buttons()
            )

        elif museum_key == "Saken Seifullin":
            info = museum_info.get("Saken Seifullin")
            await query.message.reply_text(
                f"🏛 {info['name']}\n\n"
                f"Estimated adult ticket: {info['adult_price']} KZT\n"
                f"Estimated student ticket: {info['student_price']} KZT\n\n"
                f"Working hours: {info['working_hours']}\n\n"
                f"{info['description']}\n\n"
                f"Address: {info['address']}\n\n"
                f"Note: {info['note']}",
                reply_markup=final_navigation_buttons()
            )

        else:
            await query.message.reply_text(
                "Please choose the number of adults:",
                reply_markup=museum_adult_buttons()
            )

    elif data.startswith("museum_adults_"):
        adults = int(data.replace("museum_adults_", ""))
        context.user_data["museum_adults"] = adults

        await query.message.reply_text(
            "Please choose the number of students:",
            reply_markup=museum_student_buttons()
        )

    elif data.startswith("museum_students_"):
        students = int(data.replace("museum_students_", ""))
        context.user_data["museum_students"] = students

        await query.message.reply_text(
            "Please choose the number of pupils:",
            reply_markup=museum_pupil_buttons()
        )

    elif data.startswith("museum_pupils_"):
        pupils = int(data.replace("museum_pupils_", ""))
        context.user_data["museum_pupils"] = pupils

        await query.message.reply_text(
            "How many children under 7 years old are with you?",
            reply_markup=museum_free_children_buttons()
        )

    elif data.startswith("museum_free_"):
        free_children = int(data.replace("museum_free_", ""))

        adults = context.user_data.get("museum_adults", 0)
        students = context.user_data.get("museum_students", 0)
        pupils = context.user_data.get("museum_pupils", 0)

        info = museum_info.get("National Museum")

        adult_total = adults * info["adult_price"]
        student_total = students * info["student_price"]
        pupil_total = pupils * info["pupil_price"]

        total_price = adult_total + student_total + pupil_total

        await query.message.reply_text(
            f"🏛 {info['name']}\n\n"
            f"Adult ticket: {info['adult_price']} KZT\n"
            f"Student ticket: {info['student_price']} KZT\n"
            f"Pupil ticket: {info['pupil_price']} KZT\n"
            f"Children under 7: free\n\n"
            f"Adults: {adults} × {info['adult_price']} = {adult_total} KZT\n"
            f"Students: {students} × {info['student_price']} = {student_total} KZT\n"
            f"Pupils: {pupils} × {info['pupil_price']} = {pupil_total} KZT\n"
            f"Children under 7: {free_children} (free)\n\n"
            f"Estimated total price: {total_price} KZT\n\n"
            f"Working hours: {info['working_hours']}\n"
            f"{info['cash_desk']}\n\n"
            f"{info['description']}\n\n"
            f"Address: {info['address']}\n\n"
            f"Note: {info['note']}",
            reply_markup=final_navigation_buttons()
        )

    elif data.startswith("karaoke_budget_"):

        budget = data.replace("karaoke_budget_", "")

        await query.message.reply_text(
            "Here are karaoke places for your budget:",
            reply_markup=karaoke_list_buttons(budget)
        )

    elif data.startswith("karaoke_place_"):

        place_name = data.replace("karaoke_place_", "")
        info = karaoke_info.get(place_name)

        if info:

            await query.message.reply_text(
                f"🎤 {info['name']}\n\n"
                f"{info['deposit']}\n"
                f"{info['working_hours']}\n"
                f"{info['rating']}\n\n"
                f"{info['description']}\n\n"
                f"Address: {info['address']}",
                reply_markup=final_navigation_buttons()
            )

        else:

            await query.message.reply_text(
                "Sorry, I could not find information about this karaoke place."
            )
    elif data.startswith("exhibition_type_"):
        exhibition_type = data.replace("exhibition_type_", "")
        context.user_data["exhibition_type"] = exhibition_type

        await query.message.reply_text(
            "Here are exhibition options:",
            reply_markup=exhibition_list_buttons(exhibition_type)
        )

    elif data.startswith("exhibition_place_"):
        place_name = data.replace("exhibition_place_", "")
        info = exhibition_info.get(place_name)

        if info:
            await query.message.reply_text(
                f"🖼 {info['name']}\n\n"
                f"{info['price']}\n"
                f"{info['working_hours']}\n\n"
                f"{info['description']}\n\n"
                f"Address: {info['address']}",
                reply_markup=final_navigation_buttons()
            )
        else:
            await query.message.reply_text(
                "Sorry, I could not find information about this exhibition place."
            )

    elif data.startswith("park_type_"):

        park_type = data.replace("park_type_", "")

        await query.message.reply_text(
            "Here are park options for you:",
            reply_markup=park_list_buttons(park_type)
        )

    elif data.startswith("park_place_"):

        place_name = data.replace("park_place_", "")
        info = park_info.get(place_name)

        if info:

            await query.message.reply_text(
                f"🌳 {info['name']}\n\n"
                f"{info['price']}\n"
                f"{info['working_hours']}\n\n"
                f"{info['description']}\n\n"
                f"Address: {info['address']}",
                reply_markup=final_navigation_buttons()
            )

        else:

            await query.message.reply_text(
                "Sorry, I could not find information about this park."
            )
    elif data.startswith("coworking_") and not data.startswith("coworking_place_"):
        purpose = data.replace("coworking_", "")

        await query.message.reply_text(
            "Here are coworking options for you:",
            reply_markup=coworking_list_buttons(purpose)
        )

    elif data.startswith("coworking_place_"):
        place_name = data.replace("coworking_place_", "")
        info = coworking_info.get(place_name)

        if info:
            await query.message.reply_text(
                f"💻 {info['name']}\n\n"
                f"{info['price']}\n"
                f"{info['working_hours']}\n\n"
                f"{info['description']}\n\n"
                f"Address: {info['address']}",
                reply_markup=final_navigation_buttons()
            )
        else:
            await query.message.reply_text(
                "Sorry, I could not find information about this coworking space.",
                reply_markup=final_navigation_buttons()
            )
    elif data in ["go_main_menu", "choose_category"]:

        await query.message.reply_text(
            "Where would you like to go today?",
            reply_markup=start_category_buttons()
        )
    elif data in ["go_main_menu", "choose_category"]:
        await query.message.reply_text(
            "Where would you like to go today?",
            reply_markup=InlineKeyboardMarkup([
                [InlineKeyboardButton("Cafes", callback_data="category_Cafes"),
                 InlineKeyboardButton("Restaurants", callback_data="category_Restaurants")],

                [InlineKeyboardButton("Cinema", callback_data="category_Cinema"),
                 InlineKeyboardButton("Bowling", callback_data="category_Bowling")],

                [InlineKeyboardButton("Karaoke", callback_data="category_Karaoke"),
                 InlineKeyboardButton("Coworking", callback_data="category_Coworking")],

                [InlineKeyboardButton("Oceanarium", callback_data="category_Oceanarium"),
                 InlineKeyboardButton("Exhibitions", callback_data="category_Exhibitions")],

                [InlineKeyboardButton("Museums", callback_data="category_Museums"),
                 InlineKeyboardButton("Parks", callback_data="category_Parks")]
            ])
        )

# %%
# CAFE BUTTONS AND DATA

def cafe_purpose_buttons():
    keyboard = [
        [InlineKeyboardButton("Study / Work", callback_data="cafe_purpose_study")],
        [InlineKeyboardButton("Coffee with friends", callback_data="cafe_purpose_friends")],
        [InlineKeyboardButton("Family time", callback_data="cafe_purpose_family")]
    ]

    return InlineKeyboardMarkup(keyboard)


def cafe_budget_buttons():
    keyboard = [
        [InlineKeyboardButton("Small budget", callback_data="cafe_budget_small")],
        [InlineKeyboardButton("Medium budget", callback_data="cafe_budget_medium")],
        [InlineKeyboardButton("High budget", callback_data="cafe_budget_high")]
    ]

    return InlineKeyboardMarkup(keyboard)


cafe_data = {
    "family": {
        "small": [
            {
                "name": "Chekhov",
                "address": "Tole Bi Street 61, Astana",
                "rating": "4.6",
                "average": "3,000 KZT"
            },
            {
                "name": "Alita Coffee",
                "address": "Nurmagambetova Street 27/1, Astana",
                "rating": "4.8",
                "average": "2,500 KZT"
            },
            {
                "name": "Nan Coffee",
                "address": "Satbayev Street 24, Astana",
                "rating": "4.8",
                "average": "2,000 KZT"
            }
        ],

        "medium": [
            {
                "name": "Nanmai",
                "address": "Tokpanova Street 20, Astana",
                "rating": "4.7",
                "average": "3,000 KZT"
            },
            {
                "name": "Qatty Tatty",
                "address": "Kabanbay Batyr Avenue 56, Astana",
                "rating": "4.5",
                "average": "4,000 KZT"
            },
            {
                "name": "Pate",
                "address": "Tole Bi Street 48, Astana",
                "rating": "4.6",
                "average": "5,000 KZT"
            },
            {
                "name": "Ethno Coffee",
                "address": "Kultegin Street 23, Astana",
                "rating": "4.7",
                "average": "3,500 KZT"
            }
        ],

        "high": [
            {
                "name": "Segafredo Caffe",
                "address": "Saryarka Avenue 8A, Astana",
                "rating": "4.6",
                "average": "6,000 KZT"
            },
            {
                "name": "Gasteria",
                "address": "Turan Avenue 22/1, Astana",
                "rating": "4.5",
                "average": "7,000 KZT"
            },
            {
                "name": "Coffee BOOM",
                "address": "Kabanbay Batyr Avenue 5B, Astana",
                "rating": "4.6",
                "average": "7,000 KZT"
            }
        ]
    },

    "study": {
        "small": [
            {
                "name": "Connect Multispace",
                "address": "Syganak Street 48A, Astana",
                "rating": "4.9",
                "average": "1,500 KZT"
            },
            {
                "name": "Zebra Coffee",
                "address": "Mukhamedkhanova Street 6, Astana",
                "rating": "4.8",
                "average": "2,000 KZT"
            },
            {
                "name": "Drinkit",
                "address": "Baitursynuly Street 9, Astana",
                "rating": "4.5",
                "average": "1,500 KZT"
            },
            {
                "name": "Luna Coffee",
                "address": "Mangilik El Avenue 37, Astana",
                "rating": "4.5",
                "average": "3,000 KZT"
            }
        ],

        "medium": [
            {
                "name": "Ziko",
                "address": "Turan Avenue 34A, Astana",
                "rating": "4.5",
                "average": "5,000 KZT"
            },
            {
                "name": "Peak Buro",
                "address": "Kabanbay Batyr Avenue 60/14, Astana",
                "rating": "4.6",
                "average": "4,000 KZT"
            },
            {
                "name": "Master Coffee",
                "address": "Konaev Street 35, Astana",
                "rating": "4.7",
                "average": "3,900 KZT"
            },
            {
                "name": "Sesame",
                "address": "Kabanbay Batyr Avenue 62, Astana",
                "rating": "4.7",
                "average": "5,000 KZT"
            },
            {
                "name": "Mola",
                "address": "Kabanbay Batyr Avenue 62, Astana",
                "rating": "4.7",
                "average": "5,000 KZT"
            }
        ],

        "high": [
            {
                "name": "Coffee BOOM",
                "address": "Koshkarbayev Avenue 10/1, Astana",
                "rating": "4.7",
                "average": "7,000 KZT"
            },
            {
                "name": "Zada",
                "address": "Mangilik El Avenue 61, Astana",
                "rating": "4.8",
                "average": "6,000 KZT"
            },
            {
                "name": "La Crème",
                "address": "Mangilik El Avenue 53, Astana",
                "rating": "4.6",
                "average": "7,000 KZT"
            },
            {
                "name": "Delish",
                "address": "Turkestan Street 28A, Astana",
                "rating": "4.8",
                "average": "7,000 KZT"
            },
            {
                "name": "Tary",
                "address": "Mangilik El Avenue 41/1, Astana",
                "rating": "4.6",
                "average": "7,000 KZT"
            }
        ]
    },

    "friends": {
        "small": [
            {
                "name": "Discovery Coffee",
                "address": "Satbayev Street 5, Astana",
                "rating": "4.8",
                "average": "2,000 KZT"
            },
            {
                "name": "Master Coffee Express",
                "address": "Kenesary Street 22, Astana",
                "rating": "4.8",
                "average": "2,500 KZT"
            },
            {
                "name": "New Format",
                "address": "Baitursynuly Street 14, Astana",
                "rating": "4.7",
                "average": "2,000 KZT"
            },
            {
                "name": "Vkusno Zhit",
                "address": "Tauelsizdik Avenue 34/2, Astana",
                "rating": "4.9",
                "average": "1,900 KZT"
            }
        ],

        "medium": [
            {
                "name": "Keks",
                "address": "Aliev Street 2, Astana",
                "rating": "4.7",
                "average": "3,000 KZT"
            },
            {
                "name": "Kultura Dictuet",
                "address": "Syganak Street 33, Astana",
                "rating": "4.6",
                "average": "3,500 KZT"
            },
            {
                "name": "Master Coffee",
                "address": "Respublika Avenue 10, Astana",
                "rating": "4.8",
                "average": "3,900 KZT"
            },
            {
                "name": "Bon Bon",
                "address": "Konaev Street 14/1, Astana",
                "rating": "4.6",
                "average": "5,500 KZT"
            }
        ],

        "high": [
            {
                "name": "Coffee BOOM",
                "address": "Kabanbay Batyr Avenue 5B, Astana",
                "rating": "4.6",
                "average": "7,000 KZT"
            },
            {
                "name": "Gasteria",
                "address": "Turan Avenue 22/1, Astana",
                "rating": "4.5",
                "average": "7,000 KZT"
            },
            {
                "name": "La Crème",
                "address": "Mangilik El Avenue 53, Astana",
                "rating": "4.6",
                "average": "7,000 KZT"
            }
        ]
    }
}

# %%
# RESTAURANT BUTTONS

def restaurant_cuisine_buttons():
    keyboard = [
        [InlineKeyboardButton("Kazakh food", callback_data="food_Kazakh food")],
        [InlineKeyboardButton("Italian cuisine", callback_data="food_Italian cuisine")],
        [InlineKeyboardButton("Georgian cuisine", callback_data="food_Georgian cuisine")],
        [InlineKeyboardButton("Asian food", callback_data="food_Asian food")],
        [InlineKeyboardButton("European cuisine", callback_data="food_European cuisine")]
    ]

    return InlineKeyboardMarkup(keyboard)


def restaurant_list_buttons(food_type):

    restaurant_data = {

        "Kazakh food": [
            ("Qazaq Gourmet — avg. 20k ₸", "restaurant_Qazaq Gourmet"),
            ("Aula — avg. 7–15k ₸", "restaurant_Aula"),
            ("Sandyq — avg. 15–20k ₸", "restaurant_Sandyq"),
            ("Tary — avg. 10–15k ₸", "restaurant_Tary")
        ],

        "Italian cuisine": [
            ("LA BOTTEGA — avg. 4–16k ₸", "restaurant_LA BOTTEGA"),
            ("Bella Ciao — avg. 5–15k ₸", "restaurant_Bella Ciao"),
            ("Cantinetta Antinori — avg. 20k+ ₸", "restaurant_Cantinetta Antinori"),
            ("Monte Bianco — avg. 10–20k ₸", "restaurant_Monte Bianco")
        ],

        "Georgian cuisine": [
            ("Future Restaurant — avg. 10–15k ₸", "restaurant_Future Restaurant"),
            ("Marani Cafe — avg. 15k ₸", "restaurant_Marani Cafe"),
            ("Daredzhani — avg. 6–16k ₸", "restaurant_Daredzhani"),
            ("Nino — avg. 10–18k ₸", "restaurant_Nino")
        ],

        "Asian food": [
            ("Asakusa Izakaya — avg. 20k+ ₸", "restaurant_Asakusa"),
            ("La Rivière — avg. 20k ₸", "restaurant_La Riviere"),
            ("BAO Noodles and Sushi Bar — avg. 4–6k ₸", "restaurant_BAO"),
            ("Turandot — avg. 10–20k ₸", "restaurant_Turandot")
        ],

        "European cuisine": [
            ("The Kitchen — avg. 6–16k ₸", "restaurant_The Kitchen"),
            ("Line Brew — avg. 15–20k ₸", "restaurant_Line Brew"),
            ("La Crème — avg. 12–20k ₸", "restaurant_La Creme"),
            ("ONCE — avg. 10–18k ₸", "restaurant_ONCE")
        ]
    }

    keyboard = []

    for name, callback in restaurant_data.get(food_type, []):
        keyboard.append([InlineKeyboardButton(name, callback_data=callback)])

    return InlineKeyboardMarkup(keyboard)


restaurant_info = {
    "Qazaq Gourmet": {
        "average_check": "Average check per person: 20k ₸",
        "working_hours": "Working hours: 12:00–00:00",
        "description": "Modern Kazakh fine dining restaurant with national cuisine and elegant atmosphere.",
        "address": "Mangilik El Avenue 29, Astana"
    },

    "Aula": {
        "average_check": "Average check per person: 7–15k ₸",
        "working_hours": "Working hours: 10:00–23:00",
        "description": "Stylish restaurant on the left bank with Kazakh national atmosphere.",
        "address": "Kabanbay Batyr Avenue 56, Astana"
    },

    "Sandyq": {
        "average_check": "Average check per person: 15–20k ₸",
        "working_hours": "Working hours: 11:00–00:00",
        "description": "One of the most popular Kazakh restaurants for tourists and family dinners.",
        "address": "Saraishyk Street 34/3, Astana"
    },

    "Tary": {
        "average_check": "Average check per person: 10–15k ₸",
        "working_hours": "Working hours: 10:00–23:00",
        "description": "Modern Kazakh cuisine with a stylish interior on the left bank.",
        "address": "Dostyk Street 16, Astana"
    },

    "LA BOTTEGA": {
        "average_check": "Average check per person: 4–16k ₸",
        "working_hours": "Working hours: 10:00–00:00",
        "description": "Stylish Italian restaurant in Keruen Mall.",
        "address": "Keruen Mall, Dostyk Street 9, Astana"
    },

    "Bella Ciao": {
        "average_check": "Average check per person: 5–15k ₸",
        "working_hours": "Working hours: 10:00–23:00",
        "description": "Cozy Italian restaurant with pizza and pasta.",
        "address": "Turan Avenue 53B, Astana"
    },

    "Cantinetta Antinori": {
        "average_check": "Average check per person: 20k+ ₸",
        "working_hours": "Working hours: 12:00–00:00",
        "description": "Luxury Tuscan restaurant with premium atmosphere and Italian cuisine.",
        "address": "Qadyrghali Zhalayyri Street 4, The Veil, Astana"
    },

    "Monte Bianco": {
        "average_check": "Average check per person: 10–20k ₸",
        "working_hours": "Working hours: 11:00–00:00",
        "description": "European restaurant with Italian cuisine, pasta, risotto, and steaks.",
        "address": "Kunaeva Street 14, Astana"
    },

    "Future Restaurant": {
        "average_check": "Average check per person: 10–15k ₸",
        "working_hours": "Working hours: 11:00–23:00",
        "description": "Georgian restaurant with khachapuri and khinkali.",
        "address": "Amman Street 21A, Astana"
    },

    "Marani Cafe": {
        "average_check": "Average check per person: 15k ₸",
        "working_hours": "Working hours: 11:00–23:00",
        "description": "Traditional Georgian cuisine with cozy atmosphere.",
        "address": "Saraishyk Street 6, Astana"
    },

    "Daredzhani": {
        "average_check": "Average check per person: 6–16k ₸",
        "working_hours": "Working hours: 10:00–23:00",
        "description": "Popular Georgian restaurant with authentic dishes.",
        "address": "Respublika Avenue 11, Astana"
    },

    "Nino": {
        "average_check": "Average check per person: 10–18k ₸",
        "working_hours": "Working hours: 10:00–23:00",
        "description": "Modern Georgian cuisine restaurant on the left bank.",
        "address": "Mangilik El Avenue 55, Astana"
    },

    "Asakusa": {
        "average_check": "Average check per person: 20k+ ₸",
        "working_hours": "Working hours: 12:00–00:00",
        "description": "Luxury Asian cuisine restaurant in St. Regis Astana.",
        "address": "Kabanbay Batyr Avenue 1, Astana"
    },

    "La Riviere": {
        "average_check": "Average check per person: 20k ₸",
        "working_hours": "Working hours: 12:00–00:00",
        "description": "Elegant restaurant with Mediterranean and European cuisine.",
        "address": "Kabanbay Batyr Avenue 1, Astana"
    },

    "BAO": {
        "average_check": "Average check per person: 4–6k ₸",
        "working_hours": "Working hours: 10:00–23:00",
        "description": "Casual Asian noodles and sushi restaurant.",
        "address": "Samruk Towers, Astana"
    },

    "Turandot": {
        "average_check": "Average check per person: 10–20k ₸",
        "working_hours": "Working hours: 11:00–23:00",
        "description": "Asian restaurant with elegant interior and diverse menu.",
        "address": "Saryarka Avenue 40, Astana"
    },

    "The Kitchen": {
        "average_check": "Average check per person: 6–16k ₸",
        "working_hours": "Working hours: 08:00–23:00",
        "description": "European cuisine restaurant with modern atmosphere.",
        "address": "Dostyk Street 5, Astana"
    },

    "Line Brew": {
        "average_check": "Average check per person: 15–20k ₸",
        "working_hours": "Working hours: 11:00–00:00",
        "description": "Popular European restaurant and brewery.",
        "address": "Kenesary Street 20, Astana"
    },

    "La Creme": {
        "average_check": "Average check per person: 12–20k ₸",
        "working_hours": "Working hours: 09:00–23:00",
        "description": "Elegant European restaurant with desserts and modern cuisine.",
        "address": "Mangilik El Avenue 35, Astana"
    },

    "ONCE": {
        "average_check": "Average check per person: 10–18k ₸",
        "working_hours": "Working hours: 09:00–23:00",
        "description": "Stylish European restaurant popular for dinners and meetings.",
        "address": "Mangilik El Avenue 55, Astana"
    }
}

# %%
# CINEMA BUTTONS AND DATA

def cinema_buttons():
    keyboard = [
        [InlineKeyboardButton("Chaplin Mega Silk Way", callback_data="cinema_Chaplin Mega Silk Way")],
        [InlineKeyboardButton("Chaplin Khan Shatyr", callback_data="cinema_Chaplin Khan Shatyr")],
        [InlineKeyboardButton("Kinopark 6 Keruencity", callback_data="cinema_Kinopark 6 Keruencity")],
        [InlineKeyboardButton("Arman Asia Park", callback_data="cinema_Arman Asia Park")],
        [InlineKeyboardButton("Arsenal", callback_data="cinema_Arsenal")],
        [InlineKeyboardButton("Dostar Cinema", callback_data="cinema_Dostar Cinema")],
        [InlineKeyboardButton("Keruen Cinema Talan Gallery", callback_data="cinema_Keruen Cinema Talan Gallery")]
    ]

    return InlineKeyboardMarkup(keyboard)


cinema_info = {
    "Chaplin Mega Silk Way": {
        "price": "Estimated ticket price: 3,500–5,100 KZT",
        "working_hours": "Approx. 10:00–24:00",
        "description": "A large modern cinema in MEGA Silk Way with many halls and comfortable seats.",
        "address": "MEGA Silk Way, Kabanbay Batyr Avenue 62, 2nd floor, Astana"
    },

    "Chaplin Khan Shatyr": {
        "price": "Estimated ticket price: 3,000–5,000 KZT",
        "working_hours": "Depends on movie schedule",
        "description": "A modern cinema located inside Khan Shatyr shopping mall.",
        "address": "Khan Shatyr Mall, Turan Avenue 37, 2nd floor, Astana"
    },

    "Kinopark 6 Keruencity": {
        "price": "Estimated ticket price: 2,500–4,500 KZT",
        "working_hours": "Depends on movie schedule",
        "description": "A popular cinema option in KeruenCity shopping mall.",
        "address": "KeruenCity Astana Mall, Korgalzhyn Highway 1, Astana"
    },

    "Arman Asia Park": {
        "price": "Estimated ticket price: 2,500–4,500 KZT",
        "working_hours": "Approx. 10:00–24:00",
        "description": "A cinema located in Asia Park shopping mall.",
        "address": "Asia Park Mall, Kabanbay Batyr Avenue 21, 3rd floor, Astana"
    },

    "Arsenal": {
        "price": "Estimated ticket price: 2,000–4,000 KZT",
        "working_hours": "Depends on movie schedule",
        "description": "A city cinema with regular movie screenings.",
        "address": "Ybyrai Altynsarin Street 4, Astana"
    },

    "Dostar Cinema": {
        "price": "Estimated ticket price: 2,500–4,500 KZT",
        "working_hours": "Depends on movie schedule",
        "description": "A local cinema option for watching popular movies.",
        "address": "Astana"
    },

    "Keruen Cinema Talan Gallery": {
        "price": "Estimated ticket price: around 30,000 KZT for premium sessions",
        "working_hours": "Approx. 10:00–24:00",
        "description": "A premium cinema experience in Talan Gallery.",
        "address": "Talan Gallery, Dostyk Street 16, 2nd floor, Astana"
    }
}

# %%
# BOWLING BUTTONS AND DATA

def bowling_group_buttons():
    keyboard = [
        [InlineKeyboardButton("Up to 6 people", callback_data="bowling_group_up_to_6")],
        [InlineKeyboardButton("More than 6 people", callback_data="bowling_group_more_than_6")]
    ]

    return InlineKeyboardMarkup(keyboard)


def bowling_center_buttons():
    keyboard = [
        [InlineKeyboardButton("Pingwin Premium", callback_data="bowling_center_Pingwin Premium")],
        [InlineKeyboardButton("PINgWIN Friends", callback_data="bowling_center_Pingwin Friends")],
        [InlineKeyboardButton("Hungry Rabbit", callback_data="bowling_center_Hungry Rabbit")]
    ]

    return InlineKeyboardMarkup(keyboard)


bowling_info = {
    "Pingwin Premium": {
        "name": "Pingwin Premium",
        "price": "Lane price per hour: about 4,000–5,000 KZT during the day, 5,000–7,000 KZT in the evening / prime time.",
        "capacity": "One bowling lane is usually suitable for up to 6 people.",
        "details": "A newer and more comfortable bowling center. Good for evening plans and group activities.",
        "working_hours": "Every day: approx. 09:00–05:00",
        "address": "E-565 Street 3, Astana"
    },

    "Pingwin Friends": {
        "name": "PINgWIN Friends",
        "price": "Lane price per hour: about 3,000–5,000 KZT.",
        "capacity": "One bowling lane is usually suitable for up to 6 people.",
        "details": "A more social and lively bowling place with entertainment atmosphere.",
        "working_hours": "Mon–Thu: 12:00–02:00; Fri–Sat: 11:00–03:00; Sun: 11:00–02:00",
        "address": "Yedil Street 26, Astana"
    },

    "Hungry Rabbit": {
        "name": "Hungry Rabbit",
        "price": "Lane price per hour: about 3,500 KZT during the day and 4,500 KZT in the evening.",
        "capacity": "One bowling lane is usually suitable for up to 6 people.",
        "details": "Bowling place with a restaurant area. Good option if you want to play and eat.",
        "working_hours": "Every day: approx. 12:00–02:00 / 03:00",
        "address": "Seifullin Street 38, Astana"
    }
}

# %%
# OCEANARIUM BUTTONS AND DATA

def oceanarium_adult_buttons():
    keyboard = [
        [InlineKeyboardButton("1 adult", callback_data="ocean_adults_1")],
        [InlineKeyboardButton("2 adults", callback_data="ocean_adults_2")],
        [InlineKeyboardButton("3 adults", callback_data="ocean_adults_3")],
        [InlineKeyboardButton("4 adults", callback_data="ocean_adults_4")]
    ]

    return InlineKeyboardMarkup(keyboard)


def oceanarium_free_children_buttons():
    keyboard = [
        [InlineKeyboardButton("0 children under 3", callback_data="ocean_free_0")],
        [InlineKeyboardButton("1 child under 3", callback_data="ocean_free_1")],
        [InlineKeyboardButton("2 children under 3", callback_data="ocean_free_2")]
    ]

    return InlineKeyboardMarkup(keyboard)


def oceanarium_paid_children_buttons():
    keyboard = [
        [InlineKeyboardButton("0 paid children", callback_data="ocean_paid_0")],
        [InlineKeyboardButton("1 paid child", callback_data="ocean_paid_1")],
        [InlineKeyboardButton("2 paid children", callback_data="ocean_paid_2")],
        [InlineKeyboardButton("3 paid children", callback_data="ocean_paid_3")],
        [InlineKeyboardButton("4 paid children", callback_data="ocean_paid_4")]
    ]

    return InlineKeyboardMarkup(keyboard)


oceanarium_info = {
    "name": "Ailand Oceanarium",
    "adult_price": 5400,
    "child_price": 4200,
    "working_hours": "Working hours: 10:00–22:00. Tickets can be purchased at the ticket office until 21:30.",
    "note": "Children under 3 years old can enter for free. Please check the child ticket age limit at the ticket office.",
    "description": "A family-friendly oceanarium with marine animals and aquarium zones.",
    "address": "Korgalzhyn Highway 2, Astana"
}

# %%
# MUSEUM BUTTONS AND DATA

def museum_buttons():
    keyboard = [
        [InlineKeyboardButton("National Museum", callback_data="museum_National Museum")],
        [InlineKeyboardButton("Museum of the First President", callback_data="museum_First President")],
        [InlineKeyboardButton("Saken Seifullin Museum", callback_data="museum_Saken Seifullin")]
    ]

    return InlineKeyboardMarkup(keyboard)


def museum_adult_buttons():
    keyboard = [
        [InlineKeyboardButton("1 adult", callback_data="museum_adults_1")],
        [InlineKeyboardButton("2 adults", callback_data="museum_adults_2")],
        [InlineKeyboardButton("3 adults", callback_data="museum_adults_3")],
        [InlineKeyboardButton("4 adults", callback_data="museum_adults_4")]
    ]

    return InlineKeyboardMarkup(keyboard)


def museum_student_buttons():
    keyboard = [
        [InlineKeyboardButton("0 students", callback_data="museum_students_0")],
        [InlineKeyboardButton("1 student", callback_data="museum_students_1")],
        [InlineKeyboardButton("2 students", callback_data="museum_students_2")],
        [InlineKeyboardButton("3 students", callback_data="museum_students_3")],
        [InlineKeyboardButton("4 students", callback_data="museum_students_4")]
    ]

    return InlineKeyboardMarkup(keyboard)


def museum_pupil_buttons():
    keyboard = [
        [InlineKeyboardButton("0 pupils", callback_data="museum_pupils_0")],
        [InlineKeyboardButton("1 pupil", callback_data="museum_pupils_1")],
        [InlineKeyboardButton("2 pupils", callback_data="museum_pupils_2")],
        [InlineKeyboardButton("3 pupils", callback_data="museum_pupils_3")],
        [InlineKeyboardButton("4 pupils", callback_data="museum_pupils_4")]
    ]

    return InlineKeyboardMarkup(keyboard)


def museum_free_children_buttons():
    keyboard = [
        [InlineKeyboardButton("0 children under 7", callback_data="museum_free_0")],
        [InlineKeyboardButton("1 child under 7", callback_data="museum_free_1")],
        [InlineKeyboardButton("2 children under 7", callback_data="museum_free_2")],
        [InlineKeyboardButton("3 children under 7", callback_data="museum_free_3")]
    ]

    return InlineKeyboardMarkup(keyboard)


museum_info = {
    "National Museum": {
        "name": "National Museum of Kazakhstan",
        "adult_price": 1000,
        "student_price": 700,
        "pupil_price": 500,
        "working_hours": "Tue–Sun: 09:30–18:00",
        "cash_desk": "Ticket office: 09:30–17:00",
        "description": "The largest museum in Central Asia with exhibitions about Kazakh history, culture, and art.",
        "address": "Tauelsizdik Avenue 54, Astana",
        "note": "Children under 7 years old can enter for free. Gold Hall and foreign exhibitions require an additional ticket."
    },

    "First President": {
        "name": "Museum of the First President",
        "working_hours": "Tue–Sun: approx. 10:00–18:00",
        "description": "Museum dedicated to the history of independent Kazakhstan and the first president.",
        "address": "Beibitshilik Street 11, Astana",
        "note": "Main entrance is usually free. Please check temporary exhibitions separately."
    },

    "Saken Seifullin": {
        "name": "Saken Seifullin Museum",
        "adult_price": 300,
        "student_price": 100,
        "working_hours": "Tue–Sun: 10:00–18:00",
        "description": "A historical museum dedicated to the life and literary work of Saken Seifullin.",
        "address": "Mukhtar Auezov Street 20/78, Astana",
        "note": "Ticket prices are estimated and should be checked before visiting."
    }
}

# %%
# KARAOKE BUTTONS AND DATA

def karaoke_budget_buttons():
    keyboard = [
        [InlineKeyboardButton("8,000 – 18,000 KZT per person", callback_data="karaoke_budget_low")],

        [InlineKeyboardButton("10,000 – 20,000 KZT per person", callback_data="karaoke_budget_medium")],

        [InlineKeyboardButton("15,000 – 25,000 KZT per person", callback_data="karaoke_budget_high")],

        [InlineKeyboardButton("25,000 – 30,000 KZT per person", callback_data="karaoke_budget_premium")]
    ]

    return InlineKeyboardMarkup(keyboard)


def karaoke_list_buttons(budget):

    karaoke_data = {

        "low": [
            ("Zvuk Karaoke", "karaoke_place_Zvuk"),
        ],

        "medium": [
            ("Janym Soul", "karaoke_place_Janym Soul"),
            ("Revival Karaoke", "karaoke_place_Revival"),
            ("Atmosfera Karaoke", "karaoke_place_Atmosfera")
        ],

        "high": [
            ("Pingwin Premium Karaoke", "karaoke_place_Pingwin Premium"),
            ("Queen Karaoke & Club", "karaoke_place_Queen"),
            ("Ginza Karaoke", "karaoke_place_Ginza"),
            ("Grammy Karaoke", "karaoke_place_Grammy")
        ],

        "premium": [
            ("Soprano Karaoke", "karaoke_place_Soprano"),
            ("Millionaire Karaoke", "karaoke_place_Millionaire"),
            ("Ginza Karaoke", "karaoke_place_Ginza"),
            ("Grammy Karaoke", "karaoke_place_Grammy")
        ]
    }

    keyboard = []

    for name, callback in karaoke_data.get(budget, []):
        keyboard.append([InlineKeyboardButton(name, callback_data=callback)])

    return InlineKeyboardMarkup(keyboard)


karaoke_info = {

    "Janym Soul": {
        "name": "Janym Soul",
        "deposit": "VIP deposit: about 10,000–20,000 KZT per person",
        "working_hours": "Working hours: 10:00–05:00",
        "rating": "Rating: around 5.0",
        "description": "One of the most popular karaoke places in Astana with very high reviews.",
        "address": "Beimbet Mailin Street 37A / Kerey Zhanibek Khandar Street 18, Astana"
    },

    "Soprano": {
        "name": "Soprano Karaoke",
        "deposit": "VIP deposit: about 25,000–30,000 KZT per person",
        "working_hours": "Working hours: 10:00–01:00",
        "rating": "Rating: around 4.7",
        "description": "Premium karaoke format with elegant atmosphere and stable reviews.",
        "address": "Saraishyk Street 13, Astana"
    },

    "Pingwin Premium": {
        "name": "Pingwin Premium Karaoke",
        "deposit": "VIP deposit: about 15,000–25,000 KZT per person",
        "working_hours": "Working hours: 18:00–06:00",
        "rating": "Rating: around 4.8–5.0",
        "description": "Modern premium karaoke with good service and entertainment atmosphere.",
        "address": "Shamshi Kaldayakov Street 11, Astana"
    },

    "Millionaire": {
        "name": "Millionaire Karaoke",
        "deposit": "VIP deposit: about 20,000–30,000 KZT per person",
        "working_hours": "Working hours: 18:00–05:00",
        "rating": "Rating: around 4.5–5.0",
        "description": "Elite karaoke format on the left bank, suitable for premium evenings.",
        "address": "Left bank area, Astana"
    },

    "Queen": {
        "name": "Queen Karaoke & Club",
        "deposit": "VIP deposit: about 15,000–25,000 KZT per person",
        "working_hours": "Working hours: 19:00–05:00",
        "rating": "Rating: around 5.0",
        "description": "Club and karaoke format, good for nightlife and parties.",
        "address": "Turan Avenue 21, Astana"
    },

    "Ginza": {
        "name": "Ginza Karaoke",
        "deposit": "VIP deposit: about 15,000–30,000 KZT per person",
        "working_hours": "Working hours: 18:00–05:00",
        "rating": "Rating: premium level",
        "description": "Luxury karaoke with restaurant and club atmosphere.",
        "address": "Mangilik El / left bank area, Astana"
    },

    "Revival": {
        "name": "Revival Karaoke",
        "deposit": "VIP deposit: about 10,000–20,000 KZT per person",
        "working_hours": "Working hours: 18:00–03:00",
        "rating": "Rating: good reviews",
        "description": "Classic karaoke with VIP rooms and calmer atmosphere.",
        "address": "Syganak Street 17B, Astana"
    },

    "Zvuk": {
        "name": "Zvuk Karaoke",
        "deposit": "VIP deposit: about 8,000–18,000 KZT per person",
        "working_hours": "Working hours: 18:00–04:00",
        "rating": "Rating: молодежное место",
        "description": "Youth karaoke place with good sound and more budget-friendly VIP rooms.",
        "address": "Left bank area / Turan–Saraishyk district, Astana"
    },

    "Atmosfera": {
        "name": "Atmosfera Karaoke",
        "deposit": "VIP deposit: about 10,000–20,000 KZT per person",
        "working_hours": "Working hours: 17:00–03:00",
        "rating": "Rating: cozy lounge format",
        "description": "Lounge karaoke format, more relaxed and cozy atmosphere.",
        "address": "Saraishyk / left bank area, Astana"
    },

    "Grammy": {
        "name": "Grammy Karaoke",
        "deposit": "VIP deposit: about 15,000–30,000 KZT per person",
        "working_hours": "Working hours: 18:00–05:00",
        "rating": "Rating: premium nightlife format",
        "description": "Premium club karaoke with parties and entertainment atmosphere.",
        "address": "Turan / left bank premium district, Astana"
    }
}

# %%
# EXHIBITIONS BUTTONS AND DATA

def exhibition_type_buttons():
    keyboard = [
        [InlineKeyboardButton("Technology / Science", callback_data="exhibition_type_technology")],
        [InlineKeyboardButton("Art", callback_data="exhibition_type_art")],
        [InlineKeyboardButton("Fairs / Markets", callback_data="exhibition_type_fairs")]
    ]

    return InlineKeyboardMarkup(keyboard)


def exhibition_list_buttons(exhibition_type):
    exhibition_data = {
        "technology": [
            ("EXPO / Nur Alem", "exhibition_place_Nur Alem")
        ],

        "art": [
            ("Astana Art Fair", "exhibition_place_Astana Art Fair"),
            ("ForteBank Kulanshi Art Space", "exhibition_place_Kulanshi Art Space")
        ],

        "fairs": [
            ("Congress Centre Astana", "exhibition_place_Congress Centre")
        ]
    }

    keyboard = []

    for name, callback in exhibition_data.get(exhibition_type, []):
        keyboard.append([InlineKeyboardButton(name, callback_data=callback)])

    return InlineKeyboardMarkup(keyboard)


exhibition_info = {
    "Nur Alem": {
        "name": "EXPO / Nur Alem",
        "price": "Average price: 2,000–3,000 KZT",
        "working_hours": "Working hours: 10:00–18:00",
        "description": "Technology, science, interactive exhibitions, and international projects inside the EXPO complex.",
        "address": "Mangilik El Avenue 55, Astana"
    },

    "Congress Centre": {
        "name": "Congress Centre Astana",
        "price": "Average price: often free or up to 2,000 KZT",
        "working_hours": "Working hours: depends on the event",
        "description": "Fairs, fashion exhibitions, business events, art markets, and large public events.",
        "address": "Mangilik El Avenue 57, Astana"
    },

    "Astana Art Fair": {
        "name": "Astana Art Fair",
        "price": "Entrance: around 3,000–5,000 KZT, sometimes free",
        "working_hours": "Typical event time: around 11:00–20:00",
        "description": "Contemporary art fair with galleries, artists, and international projects.",
        "address": "Congress Centre Astana, Mangilik El Avenue 57, Astana"
    },

    "Kulanshi Art Space": {
        "name": "ForteBank Kulanshi Art Space",
        "price": "Entrance: free",
        "working_hours": "Working hours: 10:00–20:00",
        "description": "Free contemporary art space with changing exhibitions and international art projects.",
        "address": "Dostyk Street 16, Astana"
    }
}

# %%
# PARKS BUTTONS AND DATA

def park_purpose_buttons():
    keyboard = [
        [InlineKeyboardButton("Walk / Relax", callback_data="park_type_walk")],
        [InlineKeyboardButton("Attractions", callback_data="park_type_attractions")],
        [InlineKeyboardButton("Sports / Activities", callback_data="park_type_sports")],
        [InlineKeyboardButton("Photo spots", callback_data="park_type_photos")],
        [InlineKeyboardButton("Family time", callback_data="park_type_family")]
    ]

    return InlineKeyboardMarkup(keyboard)


def park_list_buttons(park_type):

    park_data = {

        "walk": [
            ("Botanical Garden", "park_place_Botanical Garden"),
            ("Green Belt", "park_place_Green Belt")
        ],

        "attractions": [
            ("Ailand", "park_place_Ailand"),
            ("Dinosaur Park", "park_place_Dinosaur Park")
        ],

        "sports": [
            ("Triathlon Park", "park_place_Triathlon Park"),
            ("Botanical Garden", "park_place_Botanical Garden")
        ],

        "photos": [
            ("Botanical Garden", "park_place_Botanical Garden"),
            ("EXPO Park", "park_place_EXPO Park")
        ],

        "family": [
            ("Presidential Park", "park_place_Presidential Park"),
            ("Ailand", "park_place_Ailand")
        ]
    }

    keyboard = []

    for name, callback in park_data.get(park_type, []):
        keyboard.append([InlineKeyboardButton(name, callback_data=callback)])

    return InlineKeyboardMarkup(keyboard)


park_info = {

    "Botanical Garden": {
        "name": "Botanical Garden",
        "price": "Entrance: free",
        "working_hours": "Open daily",
        "description": "Popular place for walks, jogging, relaxing, and photo sessions.",
        "address": "Turkistan Street, Astana"
    },

    "Green Belt": {
        "name": "Green Belt",
        "price": "Entrance: free",
        "working_hours": "Open daily",
        "description": "Large green zone around Astana for nature walks and отдых.",
        "address": "Astana green zone area"
    },

    "Ailand": {
        "name": "Ailand",
        "price": "Attractions and activities have separate ticket prices",
        "working_hours": "Approx. 10:00–22:00",
        "description": "Entertainment complex with attractions, oceanarium, and family activities.",
        "address": "Korgalzhyn Highway 2, Astana"
    },

    "Dinosaur Park": {
    "name": "Dinosaur Park",
    "price": "Adult ticket: 4,500 KZT\nChild ticket: 3,500 KZT",
    "working_hours": "Approx. 10:00–22:00",
    "description": "Large dinosaur-themed park with more than 50 animated dinosaurs, sounds, and interactive atmosphere.",
    "address": "Central Park, near Beeline Arena, Astana",
    "note": "Children under 2 years old enter for free. Birthday visitors and children with disabilities can enter for free."
},

    "Triathlon Park": {
        "name": "Triathlon Park",
        "price": "Entrance: free",
        "working_hours": "Open daily",
        "description": "Popular park for sports, cycling, running, and outdoor activities.",
        "address": "Astana"
    },

    "EXPO Park": {
        "name": "EXPO Park",
        "price": "Entrance: free",
        "working_hours": "Open daily",
        "description": "Modern area near EXPO with architecture, fountains, and photo spots.",
        "address": "Mangilik El Avenue, Astana"
    },

    "Presidential Park": {
        "name": "Presidential Park",
        "price": "Entrance: free",
        "working_hours": "Open daily",
        "description": "Large family-friendly park for walks and relaxing.",
        "address": "Astana"
    }
}

# %%
# COWORKING BUTTONS AND DATA

def coworking_purpose_buttons():
    keyboard = [
        [InlineKeyboardButton("Study", callback_data="coworking_Study")],
        [InlineKeyboardButton("Quiet work", callback_data="coworking_Quiet work")],
        [InlineKeyboardButton("Work meeting", callback_data="coworking_Work meeting")],
        [InlineKeyboardButton("Creative space", callback_data="coworking_Creative space")]
    ]

    return InlineKeyboardMarkup(keyboard)


def coworking_list_buttons(purpose):
    coworking_data = {
        "Study": [
            ("iHUB Coworking", "coworking_place_iHUB"),
            ("Discovery Coworking", "coworking_place_Discovery Coworking"),
            ("Astana Hub Coworking", "coworking_place_Astana Hub")
        ],

        "Quiet work": [
            ("IQ Coworking", "coworking_place_IQ Coworking"),
            ("OD Coworking", "coworking_place_OD Coworking"),
            ("Discovery Coworking", "coworking_place_Discovery Coworking")
        ],

        "Work meeting": [
            ("Regus Emerald Tower", "coworking_place_Regus Emerald Tower"),
            ("Connect Multispace", "coworking_place_Connect Multispace"),
            ("IQ Coworking", "coworking_place_IQ Coworking")
        ],

        "Creative space": [
            ("Astana Hub Coworking", "coworking_place_Astana Hub"),
            ("iHUB Coworking", "coworking_place_iHUB"),
            ("Connect Multispace", "coworking_place_Connect Multispace")
        ]
    }

    keyboard = []

    for name, callback in coworking_data.get(purpose, []):
        keyboard.append([InlineKeyboardButton(name, callback_data=callback)])

    return InlineKeyboardMarkup(keyboard)


coworking_info = {
    "IQ Coworking": {
        "name": "IQ Coworking",
        "price": "Price: from 2,000–5,000 KZT per day",
        "working_hours": "Working hours: 24/7",
        "description": "One of the most convenient and popular coworking spaces in the center. It has quiet zones, meeting rooms, and good internet.",
        "address": "Dostyk Street 5, Astana"
    },

    "iHUB": {
        "name": "iHUB Coworking",
        "price": "Price: 2,000–6,000 KZT per day",
        "working_hours": "Working hours: 09:00–21:00",
        "description": "Good for students, freelancers, and startups. Events and networking sessions are often held here.",
        "address": "Konaev Street 12/1, Astana"
    },

    "Discovery Coworking": {
        "name": "Discovery Coworking",
        "price": "Price: 2,000–5,000 KZT per day",
        "working_hours": "Working hours: 09:00–22:00",
        "description": "A calm place without much noise. Good for studying and working with a laptop.",
        "address": "Dostyk Street 5, Astana"
    },

    "Astana Hub": {
        "name": "Astana Hub Coworking",
        "price": "Price: often free with registration",
        "working_hours": "Working hours: 09:00–18:30 on weekdays",
        "description": "The main IT hub of Kazakhstan. Startups, IT teams, lectures, and events are based here. Entry may require registration.",
        "address": "Mangilik El Avenue 55/8, Astana"
    },

    "Connect Multispace": {
        "name": "Connect Multispace",
        "price": "Price: 3,000–7,000 KZT per day",
        "working_hours": "Working hours: 09:00–22:00",
        "description": "Comfortable coworking with rest zones, meeting rooms, and a cafe. Modern and convenient format.",
        "address": "Syganak Street 48A, Astana"
    },

    "Regus Emerald Tower": {
        "name": "Regus Emerald Tower",
        "price": "Price: from 10,000 KZT per day",
        "working_hours": "Working hours: 24/7",
        "description": "Premium business coworking with quiet office atmosphere. Good for serious work and meetings.",
        "address": "Konaev Street 10, Astana"
    },

    "Work Space Coworking": {
        "name": "Work Space Coworking",
        "price": "Price: 2,000–5,000 KZT per day",
        "working_hours": "Working hours: 09:00–00:00",
        "description": "Budget-friendly option. Simple, but suitable for working.",
        "address": "A 92 Street 5, Astana"
    },

    "OD Coworking": {
        "name": "OD Coworking",
        "price": "Price: 3,000–6,000 KZT per day",
        "working_hours": "Working hours: 09:00–18:00",
        "description": "Small coworking space with minimal noise. Good for calm and focused work.",
        "address": "Turan Avenue 50/3, Astana"
    }
}

# %%
import nest_asyncio
import asyncio

nest_asyncio.apply()


async def main():
    app = Application.builder().token(TOKEN).build()

    app.add_handler(CommandHandler("start", start))
    app.add_handler(CallbackQueryHandler(button_handler))

    print("Bot is running...")
    await app.run_polling()


asyncio.get_event_loop().run_until_complete(main())
# Out:
# Bot is running...
# Button clicked: category_Cinema
# Button clicked: category_Cinema
# Button clicked: cinema_Arman Asia Park
# Button clicked: cinema_Arman Asia Park
# Button clicked: go_main_menu
# Button clicked: category_Bowling
# Button clicked: category_Bowling
# Button clicked: bowling_group_more_than_6
# Button clicked: bowling_group_more_than_6
# Button clicked: bowling_center_Hungry Rabbit
# Button clicked: bowling_center_Hungry Rabbit
# Button clicked: go_main_menu
